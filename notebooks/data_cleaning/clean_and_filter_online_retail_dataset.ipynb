# %% [markdown]
# ## Setup

# %%
import requests
import zipfile
import io
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import pytz
import numpy as np
import pandas as pd
import math
import warnings
import seaborn as sns
import os
import shutil
import re
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from tqdm import tqdm

# Suppress specific warnings (in this case, FutureWarnings)
warnings.simplefilter(action='ignore', category=FutureWarning)

np.random.seed(42)

# %%
def human_format(num):
  """Convert a number to a human readable version, e.g. 10M for 10,000,000."""
  if num == 0:
    return '0'
  letters = ["", "K", "M", "B", "T"]
  scale = math.floor(math.log10(abs(num)) / 3)
  # Convert to string: truncate to scale, remove trailing zeros and decimal points
  num = float('{:.3g}'.format(num)) / 10**(3*scale)
  num_str = str(num).rstrip('0').rstrip('.')
  # Append scale letter
  return f'{num_str}{letters[int(scale)]}'

def mpl_human_format(x, pos):
  """Formatter for matplotlib to use human_format."""
  if pos is not None:
    return human_format(x)
  return ''

def make_axes_human_readable(ax, axis="y"):
  """Apply human readable formatting to the specified axis of a matplotlib axes object."""
  if axis.lower() == 'x':
    axisvar = ax.xaxis
  elif axis.lower() == 'y':
    axisvar = ax.yaxis
  else:
    raise ValueError("Must specify axis as either 'x' or 'y'")

  axisvar.set_major_formatter(ticker.FuncFormatter(mpl_human_format))
  return ax

# %% [markdown]
# ## Download dataset

# %%
# Data from https://archive.ics.uci.edu/dataset/502/online+retail+ii
DATASET_URL = 'https://archive.ics.uci.edu/static/public/502/online+retail+ii.zip'
DATASET_FILENAME = 'online_retail_II.xlsx'

response = requests.get(DATASET_URL)
zip_bytes = io.BytesIO(response.content)

with zipfile.ZipFile(zip_bytes) as z:
    with z.open(DATASET_FILENAME) as file:
        # Load all sheets
        all_sheets = pd.read_excel(file, sheet_name=None)

# Combine into one DataFrame
online_retail_df = pd.concat(all_sheets.values(), ignore_index=True)

online_retail_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ## Clean data

# %%
def normalize(text):
    if pd.isnull(text):
        return np.nan
    text = text.lower()  # lowercase
    text = re.sub(r'[^a-z0-9\s]', '', text)  # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra spaces
    return text

# %%
cleaned_online_retail_df = online_retail_df.copy()

cleaned_online_retail_df = cleaned_online_retail_df[[
    'InvoiceDate',
    'StockCode',
    'Description',
    'Quantity',
    'Price',
]]
cleaned_online_retail_df = cleaned_online_retail_df.query('Quantity > 0 and Price > 0')
cleaned_online_retail_df.loc[:,'Description'] = cleaned_online_retail_df['Description'].astype(str).apply(normalize)
cleaned_online_retail_df.loc[:,'StockCode'] = cleaned_online_retail_df['StockCode'].astype(str).str.upper()

cleaned_online_retail_df = cleaned_online_retail_df.dropna(axis=0)

description_exclusion_list = {
    '?',
    'checked',
    'found',
    'mailout',
    'temp',
    'update',
    'damaged',
    'amazon',
    'amazon adjustment',
    'amendment',
    'this is a test product',
    'temp',
    'postage',
    'dotcom postage',
    'manual',
    'carriage',
    '',
}

description_exclusion_mask = ~cleaned_online_retail_df['Description'].isin(description_exclusion_list)

cleaned_online_retail_df = cleaned_online_retail_df[description_exclusion_mask]

cleaned_online_retail_df
# Out:
#                 InvoiceDate StockCode                          Description  \
# 0       2009-12-01 07:45:00     85048  15cm christmas glass ball 20 lights
# 1       2009-12-01 07:45:00    79323P                   pink cherry lights
# 2       2009-12-01 07:45:00    79323W                  white cherry lights
# 3       2009-12-01 07:45:00     22041           record frame 7 single size
# 4       2009-12-01 07:45:00     21232       strawberry ceramic trinket box
# ...                     ...       ...                                  ...
# 1067365 2011-12-09 12:50:00     22613          pack of 20 spaceboy napkins
# 1067366 2011-12-09 12:50:00     22899           childrens apron dolly girl
# 1067367 2011-12-09 12:50:00     23254         childrens cutlery dolly girl
# 1067368 2011-12-09 12:50:00     23255      childrens cutlery circus parade
# 1067369 2011-12-09 12:50:00     22138         baking set 9 piece retrospot
#
#          Quantity  Price
# 0              12   6.95
# ...

# %%
# Create a mapping of original to canonical names
canonical = {}
threshold = 85  # similarity score threshold

for item in tqdm(cleaned_online_retail_df['Description'].unique()):
    matched = None
    for key in canonical:
        if fuzz.ratio(item, key) >= threshold:
            matched = key
            break
    if matched:
        canonical[item] = matched
    else:
        canonical[item] = item

canonical = {key: canonical[key] for key in canonical if key != canonical[key]}

for key in canonical:
    print(f'{key} => {canonical[key]}')
# Out:
# 100%|██████████| 5281/5281 [00:15<00:00, 344.28it/s]
# home building block word => love building block word
# bath building block word => home building block word
# feltcraft doll maria => feltcraft doll rosie
# feltcraft doll emily => feltcraft doll maria
# charlie lola blue hot water bottle => charlielola red hot water bottle
# charlielola pink hot water bottle => charlielola red hot water bottle
# charlie lola red hot water bottle => charlielola red hot water bottle
# carrot charlielola coaster set => tomato charlielola coaster set
# charlie lola wastepaper bin flora => charlie lola wastepaper bin blue
# kings choice giant tube matches => kings choice small tube matches
# blue felt hanging heart w flower => pink felt hanging heart w flower
# set6 woodland paper plates => set6 woodland paper cups
# red hanging heart tlight holder => hanging heart zinc tlight holder
# feltcraft doll molly => feltcraft doll emily
# girls alphabet iron on patches => boys alphabet iron on patches
# ...

# %%
cleaned_online_retail_df.loc[:,'FuzzedDescription'] = cleaned_online_retail_df['Description'].replace(canonical)
cleaned_online_retail_df.loc[:,'Revenue'] = cleaned_online_retail_df['Quantity'] * cleaned_online_retail_df['Price']

cleaned_online_retail_df = cleaned_online_retail_df.set_index('InvoiceDate')

cleaned_online_retail_df = cleaned_online_retail_df.groupby(by=[
    pd.Grouper(freq='D'),  # resample to daily
    'FuzzedDescription',
]).agg({
    'Description': ['unique', 'nunique'],
    'StockCode': ['unique', 'nunique'],
    'Quantity': 'sum',
    'Revenue': 'sum',
})

cleaned_online_retail_df.columns = [
    f"{col[0]}_{col[1]}" if col[1] else col[0]
    for col in cleaned_online_retail_df.columns.values
]

cleaned_online_retail_df
# Out:
#                                                                               Description_unique  \
# InvoiceDate FuzzedDescription
# 2009-12-01  12 ass zinc christmas decorations                [12 ass zinc christmas decorations]
#             12 egg house painted wood          [12 egg house painted wood, 6 egg house painte...
#             12 mini toadstool pegs                                      [12 mini toadstool pegs]
#             12 pencils small tube red spotty                  [12 pencils small tube red spotty]
#             12 pencils tall tube posy          [12 pencils tall tube posy, 12 pencils tall tu...
# ...                                                                                          ...
# 2011-12-09  youre confusing me metal sign                        [youre confusing me metal sign]
#             zinc folkart sleigh bells                                [zinc folkart sleigh bells]
# ...

# %% [markdown]
# ## Filter products

# %%
info_by_fuzzed_description = cleaned_online_retail_df.reset_index().groupby('FuzzedDescription').agg({
    'InvoiceDate': ['min', 'max', 'nunique'],
    'Quantity_sum': 'sum',
    'Revenue_sum': 'sum',
})

info_by_fuzzed_description = pd.DataFrame(
    index = info_by_fuzzed_description.index,
    data={
        'MinDate': info_by_fuzzed_description['InvoiceDate']['min'],
        'MaxDate': info_by_fuzzed_description['InvoiceDate']['max'],
        'NumDaysWithSales': info_by_fuzzed_description['InvoiceDate']['nunique'],
        'TotalSold': info_by_fuzzed_description['Quantity_sum']['sum'],
        'RevenuePounds': info_by_fuzzed_description['Revenue_sum']['sum'],
    }
)

info_by_fuzzed_description['NumDaysSpanned'] = (info_by_fuzzed_description['MaxDate'] - info_by_fuzzed_description['MinDate']).dt.days + 1
info_by_fuzzed_description.loc[:,'DaysWithSalesDensity'] = info_by_fuzzed_description['NumDaysWithSales'] / info_by_fuzzed_description['NumDaysSpanned']

info_by_fuzzed_description
# Out:
#                                      MinDate    MaxDate  NumDaysWithSales  \
# FuzzedDescription
# 10 colour spaceboy pen            2010-05-06 2011-12-09               313
# 11 pc ceramic tea set polkadot    2009-12-08 2009-12-08                 1
# 12 ass zinc christmas decorations 2009-12-01 2010-10-20                61
# 12 coloured party balloons        2010-04-07 2011-12-07               207
# 12 daisy pegs in wood box         2009-12-02 2011-10-16               171
# ...                                      ...        ...               ...
# zinc police box lantern           2009-12-01 2010-03-14                 6
# zinc sweetheart wire letter rack  2011-04-18 2011-12-08               135
# zinc tlight holder stars small    2011-04-21 2011-12-09               157
# zinc top 2 door wooden shelf      2009-12-08 2011-11-10                47
# zinc willie winkie candle stick   2009-12-01 2011-12-09               354
#
# ...

# %%
info_by_fuzzed_description['NumDaysSpanned'].describe()
# Out:
# count    4069.000000
# mean      451.876628
# std       264.529049
# min         1.000000
# 25%       197.000000
# 50%       501.000000
# 75%       726.000000
# max       739.000000
# Name: NumDaysSpanned, dtype: float64

# %%
info_by_fuzzed_description['MinDate'].describe()
# Out:
# count                             4069
# mean     2010-04-12 21:40:55.148685056
# min                2009-12-01 00:00:00
# 25%                2009-12-01 00:00:00
# 50%                2009-12-07 00:00:00
# 75%                2010-06-07 00:00:00
# max                2011-12-09 00:00:00
# Name: MinDate, dtype: object

# %%
info_by_fuzzed_description['MaxDate'].describe()
# Out:
# count                             4069
# mean     2011-07-07 18:43:15.822069504
# min                2009-12-01 00:00:00
# 25%                2011-03-09 00:00:00
# 50%                2011-12-01 00:00:00
# 75%                2011-12-08 00:00:00
# max                2011-12-09 00:00:00
# Name: MaxDate, dtype: object

# %%
start_date = info_by_fuzzed_description['MinDate'].values
density_bin = (info_by_fuzzed_description['DaysWithSalesDensity'].values // 0.10) * 0.10 * 100
num_days_spanned_bin = (info_by_fuzzed_description['NumDaysSpanned'] // 10) * 10

fig, ax = plt.subplots(figsize=(10, 6))  # Create a figure and an axes

sc = ax.scatter(
    start_date, 
    density_bin, 
    c=num_days_spanned_bin, 
    cmap='plasma', 
    s=100,
    edgecolor='k'
)

# Add colorbar linked to the scatter plot
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label('Number of days spanned')

# Set labels and title
ax.set_xlabel('Start date')
ax.set_ylabel('Days with sales density (%)')
ax.set_title('Density over Time with Span Encoded as Color')
ax.grid(True)
ax.set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
products_to_keep = (
    info_by_fuzzed_description
    .query('NumDaysSpanned >= 600 and DaysWithSalesDensity >= 0.60')
    .index
    .values
)
products_to_keep
# Out:
# array(['12 pencils small tube red spotty', '12 pencils tall tube posy',
#        '12 pencils tall tube woodland', '6 ribbons rustic charm',
#        '60 teatime fairy cake cases', '72 sweetheart fairy cake cases',
#        'antique silver tea glass etched', 'assorted colour bird ornament',
#        'bag 500g swirly marbles', 'baking set 9 piece retrospot',
#        'baking set spaceboy design', 'bathroom metal sign',
#        'blue happy birthday bunting', 'blue harmonica in box',
#        'box of 24 cocktail parasols', 'charlotte bag suki design',
#        'childs apron spaceboy design', 'chocolate this way metal sign',
#        'colour glass tlight holder hanging', 'cook with wine metal sign',
#        'cream heart card holder', 'cream sweetheart mini chest',
#        'door mat fairy cake', 'door mat fancy font home sweet home',
#        'door mat new england', 'door mat spotty home sweet home',
#        'door mat union flag', 'doormat hearts',
# ...

# %%
mask = info_by_fuzzed_description.index.isin(products_to_keep)

products_to_keep_info = info_by_fuzzed_description[mask]
products_to_exclude_info = info_by_fuzzed_description[~mask]

# %%
x = np.linspace(
    min(products_to_keep_info['NumDaysSpanned'].min(), products_to_exclude_info['NumDaysSpanned'].min()),
    max(products_to_keep_info['NumDaysSpanned'].max(), products_to_exclude_info['NumDaysSpanned'].max()),
    100
)

fig, ax = plt.subplots(figsize=(7,5))

ax.scatter(
    products_to_exclude_info['NumDaysSpanned'],
    products_to_exclude_info['NumDaysWithSales'],
    color='grey',
    alpha=0.4,
    label='Excluded products'
)

ax.scatter(
    products_to_keep_info['NumDaysSpanned'],
    products_to_keep_info['NumDaysWithSales'],
    color='tab:blue',
    alpha=1,
    label='Included products'
)

ax.plot(x, x, color='tab:green', label='100% coverage')
ax.plot(x, 0.8 * x, color='tab:orange', label='80% coverage')
ax.plot(x, 0.6 * x, color='tab:red', label='60% coverage')

ax.axvline(600, color='black', linestyle='--', label='600 days')

ax.set_title('Num days with sales vs. total days spanned')
ax.set_xlabel('Total days spanned')
ax.set_ylabel('Num days with sales')
ax.grid(True, which='both')
ax.set_axisbelow(True)
ax.legend()

plt.tight_layout()
plt.show()

# %%
products_to_keep_count = len(products_to_keep_info.index)
products_to_exclude_count = len(products_to_exclude_info.index)

products_to_keep_total_sales = products_to_keep_info['TotalSold'].sum()
products_to_exclude_total_sales = products_to_exclude_info['TotalSold'].sum()

products_to_keep_total_revenue = products_to_keep_info['RevenuePounds'].sum()
products_to_exclude_total_revenue = products_to_exclude_info['RevenuePounds'].sum()

count_data = [products_to_keep_count, products_to_exclude_count]
sales_data = [products_to_keep_total_sales, products_to_exclude_total_sales]
revenue_data = [products_to_keep_total_revenue, products_to_exclude_total_revenue]
labels = ['Included products', 'Excluded products']
colors = ['tab:blue', 'grey']  # Customize your slice colors here

def format_value(val):
    if val >= 10_000:
        return f"{val/10_000:.1f}".rstrip('0').rstrip('.') + 'K'
    elif val >= 1000:
        return f"{val/1000:.1f}".rstrip('0').rstrip('.') + 'K'
    else:
        return str(round(val))

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = pct * total / 100.0
        return f'{pct:.0f}% = {format_value(val)}'
    return my_autopct

# Plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))

# First pie: product count
wedges, _, _ = ax.pie(
    count_data,
    # labels=labels,
    autopct=make_autopct(count_data),
    startangle=90,
    colors=colors
)
ax.set_title("Product Count")
ax.legend(labels)

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))

# First pie: product count
wedges, _, _ = ax.pie(
    sales_data,
    # labels=labels,
    autopct=make_autopct(sales_data),
    startangle=90,
    colors=colors
)
ax.set_title("Product Sales (units)")
ax.legend(labels)

plt.tight_layout()
plt.show()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))

# First pie: product count
wedges, _, _ = ax.pie(
    revenue_data,
    # labels=labels,
    autopct=make_autopct(revenue_data),
    startangle=90,
    colors=colors
)
ax.set_title("Product Sales (Pounds)")
ax.legend(labels)

plt.tight_layout()
plt.show()

# %%
products_to_keep_info['NumDaysSpanned'].describe()
# Out:
# count    142.000000
# mean     717.521127
# std       39.631766
# min      608.000000
# 25%      726.500000
# 50%      739.000000
# 75%      739.000000
# max      739.000000
# Name: NumDaysSpanned, dtype: float64

# %%
start_dates = products_to_keep_info['MinDate'].values

fig, ax = plt.subplots(figsize=(7,4))

n, bins, patches = ax.hist(start_dates, bins=len(np.unique(start_dates)))

ax.set_title('Start Date Distribution for Selected Products')
ax.set_xlabel('Date')
ax.set_ylabel('Number of products')
ax.grid(True, which='both')

ax2 = ax.twinx()

total_products = len(start_dates)
percentages = np.round((n / total_products) * 100, 0)

ax2.set_ylabel('Percentage of products')

yticks_count = ax.get_yticks()
yticks_percentage = np.round((yticks_count / total_products) * 100, 1)
ax2.set_yticks(yticks_count)
ax2.set_yticklabels([f'{p:.0f}%' for p in yticks_percentage])

plt.tight_layout()
plt.show()

# %%
end_dates = products_to_keep_info['MaxDate'].values

fig, ax = plt.subplots(figsize=(7,4))

n, bins, patches = ax.hist(end_dates, bins=len(np.unique(end_dates)))

ax.set_title('End Date Distribution for Selected Products')
ax.set_xlabel('Date')
ax.set_ylabel('Number of products')
ax.grid(True, which='both')

ax2 = ax.twinx()

total_products = len(end_dates)
percentages = np.round((n / total_products) * 100, 0)

ax2.set_ylabel('Percentage of products')

yticks_count = ax.get_yticks()
yticks_percentage = np.round((yticks_count / total_products) * 100, 1)
ax2.set_yticks(yticks_count)
ax2.set_yticklabels([f'{p:.0f}%' for p in yticks_percentage])

plt.tight_layout()
plt.show()

# %%
start_dates = products_to_exclude_info['MinDate'].values

fig, ax = plt.subplots(figsize=(7,4))

n, bins, patches = ax.hist(start_dates, bins=20)

ax.set_title('Start Date Distribution for Excluded Products')
ax.set_xlabel('Date')
ax.set_ylabel('Number of products')
ax.grid(True, which='both')
make_axes_human_readable(ax)

ax2 = ax.twinx()

total_products = len(start_dates)
percentages = np.round((n / total_products) * 100, 0)

ax2.set_ylabel('Percentage of products')

yticks_count = ax.get_yticks()
yticks_percentage = np.round((yticks_count / total_products) * 100, 1)
ax2.set_yticks(yticks_count)
ax2.set_yticklabels([f'{p:.0f}%' for p in yticks_percentage])

plt.tight_layout()
plt.show()

# %%
cleaned_online_retail_mask = cleaned_online_retail_df.reset_index()['FuzzedDescription'].isin(products_to_keep).values

cleaned_online_reatail_to_keep = cleaned_online_retail_df[cleaned_online_retail_mask]
cleaned_online_reatail_to_remove = cleaned_online_retail_df[~cleaned_online_retail_mask]

# %%
fuzzed_description_to_descriptions_df = cleaned_online_reatail_to_keep.reset_index()[[
    'FuzzedDescription',
    'Description_unique',
]].explode('Description_unique').groupby('FuzzedDescription').agg({
    'Description_unique': ['unique', 'nunique']
})

fuzzed_description_to_descriptions_df.columns = fuzzed_description_to_descriptions_df.columns.droplevel(0)

fuzzed_description_to_descriptions_df
# Out:
#                                                                               unique  \
# FuzzedDescription
# 12 pencils small tube red spotty   [12 pencils small tube red spotty, 12 pencils ...
# 12 pencils tall tube posy          [12 pencils tall tube posy, 12 pencils tall tu...
# 12 pencils tall tube woodland      [12 pencils tall tube woodland, 12 pencil smal...
# 6 ribbons rustic charm                                      [6 ribbons rustic charm]
# 60 teatime fairy cake cases                            [60 teatime fairy cake cases]
# ...                                                                              ...
# wooden rounders garden set         [wooden rounders garden set, wooden croquet ga...
# wooden school colouring set                            [wooden school colouring set]
# woodland charlotte bag                                      [woodland charlotte bag]
# world war 2 gliders asstd designs                [world war 2 gliders asstd designs]
# ...

# %%
fuzzed_description_to_descriptions_df.query('nunique > 1').sort_values(by='nunique', ascending=False)['unique'].values
# Out:
# array([array(['ivory hanging decoration heart',
#               'ivory hanging decoration chicken',
#               'ivory hanging decoration bird', 'ivory hanging decoration egg',
#               'ivory hanging decoration rabbit'], dtype=object)               ,
#        array(['set10 pink spotty party candles',
#               'set10 blue spotty party candles',
#               'set10 red spotty party candles',
#               'set10 ivory spotty party candles',
#               'set10 pink polkadot party candles'], dtype=object),
#        array(['hanging heart zinc tlight holder',
#               'red hanging heart tlight holder',
#               'single heart zinc tlight holder',
#               'hanging heart jar tlight holder'], dtype=object),
#        array(['12 pencils tall tube posy', '12 pencils tall tube skulls',
#               '12 pencils tall tube red spotty', '12 pencils small tube posy'],
#              dtype=object)                                                     ,
# ...

# %%
pivoted_clean_data_to_keep = cleaned_online_reatail_to_keep.reset_index()[[
    'InvoiceDate',
    'FuzzedDescription',
    'Quantity_sum',
]].pivot(index='InvoiceDate', columns='FuzzedDescription', values='Quantity_sum')

pivoted_clean_data_to_remove = cleaned_online_reatail_to_remove.reset_index()[[
    'InvoiceDate',
    'FuzzedDescription',
    'Quantity_sum',
]].pivot(index='InvoiceDate', columns='FuzzedDescription', values='Quantity_sum')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

pivoted_clean_data_to_keep.plot(ax=ax)

ax.set_title('Daily Purchase Quantity by Product\nProducts to Keep')
ax.set_xlabel('Date')
ax.set_ylabel('Units sold')
ax.legend().remove()
ax.grid(True, which='both')
make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

pivoted_clean_data_to_remove.plot(ax=ax)

ax.set_title('Daily Purchase Quantity by Product\nProducts to Remove')
ax.set_xlabel('Date')
ax.set_ylabel('Units sold')
ax.legend().remove()
ax.grid(True, which='both')
make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5))

pivoted_clean_data_to_remove.plot(ax=ax)

ax.set_title('Daily Purchase Quantity by Product\nProducts to Remove')
ax.set_xlabel('Date')
ax.set_ylabel('Units sold')
ax.legend().remove()
ax.grid(True, which='both')
ax.set_ylim(None, 5_000)
make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %%
selected_products = np.random.choice(pivoted_clean_data_to_keep.columns.values, size=4)

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15,10))

fig.suptitle('Sample Products to Keep', fontweight='bold')

axs = axs.flatten()

for ax, product in zip(axs, selected_products):
    pivoted_clean_data_to_keep[product].fillna(0).plot(ax=ax)
    ax.set_title(product.capitalize())
    ax.set_xlabel('Date')
    ax.set_ylabel('Units sold')
    ax.grid(True, which='both')
    make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %%
selected_products = np.random.choice(pivoted_clean_data_to_remove.columns.values, size=4)

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15,10))

fig.suptitle('Sample Products to Remove', fontweight='bold')

axs = axs.flatten()

for ax, product in zip(axs, selected_products):
    pivoted_clean_data_to_remove[product].fillna(0).plot(ax=ax)
    ax.set_title(product.capitalize())
    ax.set_xlabel('Date')
    ax.set_ylabel('Units sold')
    ax.grid(True, which='both')
    make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save data

# %%
data_to_save = cleaned_online_reatail_to_keep.copy().reset_index()
data_to_save = data_to_save[['InvoiceDate', 'FuzzedDescription', 'Quantity_sum', 'Revenue_sum']]
data_to_save = data_to_save.rename(columns={
    'InvoiceDate': 'Date',
    'FuzzedDescription': 'Description',
    'Quantity_sum': 'UnitsSold',
    'Revenue_sum': 'RevenuePounds',
})
data_to_save.loc[:,'AveragePricePerUnitPounds'] = (data_to_save['RevenuePounds'] / data_to_save['UnitsSold']).round(2)

# Fill in missing dates
expected_dates = pd.date_range(start=data_to_save["Date"].min(), end=data_to_save["Date"].max(), freq="D")
all_products = data_to_save['Description'].unique()
full_index = pd.MultiIndex.from_product(
    [all_products, expected_dates],
    names=['Description', 'Date'])

data_to_save = (
    data_to_save
    .set_index(["Description", "Date"])
    .reindex(full_index)
    .reset_index()
)

data_to_save['UnitsSold'] = data_to_save['UnitsSold'].fillna(0)
data_to_save['RevenuePounds'] = data_to_save['RevenuePounds'].fillna(0)
data_to_save['AveragePricePerUnitPounds'] = data_to_save['AveragePricePerUnitPounds'].fillna(method='bfill')

data_to_save
# Out:
#                               Description       Date  UnitsSold  \
# 0        12 pencils small tube red spotty 2009-12-01       45.0
# 1        12 pencils small tube red spotty 2009-12-02       87.0
# 2        12 pencils small tube red spotty 2009-12-03       34.0
# 3        12 pencils small tube red spotty 2009-12-04       84.0
# 4        12 pencils small tube red spotty 2009-12-05        0.0
# ...                                   ...        ...        ...
# 104933  wood black board ant white finish 2011-12-05       23.0
# 104934  wood black board ant white finish 2011-12-06        4.0
# 104935  wood black board ant white finish 2011-12-07       70.0
# 104936  wood black board ant white finish 2011-12-08      226.0
# 104937  wood black board ant white finish 2011-12-09        2.0
#
#         RevenuePounds  AveragePricePerUnitPounds
# 0               29.90                       0.66
# 1               61.75                       0.71
# ...

# %%
data_to_save.groupby('Description').count()
# Out:
#                                    Date  UnitsSold  RevenuePounds  \
# Description
# 12 pencils small tube red spotty    739        739            739
# 12 pencils tall tube posy           739        739            739
# 12 pencils tall tube woodland       739        739            739
# 6 ribbons rustic charm              739        739            739
# 60 teatime fairy cake cases         739        739            739
# ...                                 ...        ...            ...
# wooden rounders garden set          739        739            739
# wooden school colouring set         739        739            739
# woodland charlotte bag              739        739            739
# world war 2 gliders asstd designs   739        739            739
# zinc metal heart decoration         739        739            739
#
#                                    AveragePricePerUnitPounds
# Description
# 12 pencils small tube red spotty                         739
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))

data_to_save.groupby('Date')['UnitsSold'].sum().plot(ax=ax)

ax.set_title('Total Units Sold for Selected Products')
ax.set_xlabel('Date')
ax.set_ylabel('Units sold')
ax.grid(True, which='both')
make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))

data_to_save.groupby('Date')['RevenuePounds'].sum().plot(ax=ax)

ax.set_title('Total Revenue for Selected Products')
ax.set_xlabel('Date')
ax.set_ylabel('Pounds')
ax.grid(True, which='both')
make_axes_human_readable(ax)

plt.tight_layout()
plt.show()

# %%
DIR_TO_SAVE_TO = '../../dataset/online_retail_data/'
FILENAME = 'online_retail.json'

os.makedirs(DIR_TO_SAVE_TO, exist_ok=True)

filepath = os.path.join(DIR_TO_SAVE_TO, FILENAME)

data_to_save.to_json(
    filepath,
    orient='records',
    date_format='iso',
    indent=4,
    index=False,
)

# %%
pd.read_json(filepath)
# Out:
#                               Description       Date  UnitsSold  \
# 0        12 pencils small tube red spotty 2009-12-01         45
# 1        12 pencils small tube red spotty 2009-12-02         87
# 2        12 pencils small tube red spotty 2009-12-03         34
# 3        12 pencils small tube red spotty 2009-12-04         84
# 4        12 pencils small tube red spotty 2009-12-05          0
# ...                                   ...        ...        ...
# 104933  wood black board ant white finish 2011-12-05         23
# 104934  wood black board ant white finish 2011-12-06          4
# 104935  wood black board ant white finish 2011-12-07         70
# 104936  wood black board ant white finish 2011-12-08        226
# 104937  wood black board ant white finish 2011-12-09          2
#
#         RevenuePounds  AveragePricePerUnitPounds
# 0               29.90                       0.66
# 1               61.75                       0.71
# ...
